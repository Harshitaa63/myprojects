# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitaa63/myprojects/blob/main/NLP_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords

# Download the stopwords resource if not already present
try:
    stopwords.words('english')
except LookupError:
    nltk.download('stopwords')

# Get english stopword
english_stopwords=set(stopwords.words('english'))
# print stopword
print(english_stopwords)
# Out:
# {'hers', 'she', 'but', 'such', "they'd", 'hadn', 'before', 'why', 'do', 'themselves', 'can', 'have', "shan't", "didn't", "won't", 'about', 'did', 're', 'are', 'where', 'doing', 'isn', "hadn't", 'off', 've', 'those', "wouldn't", 'and', 'being', 'mightn', 'were', 'ourselves', 'against', 'y', 'herself', "couldn't", 'her', 'each', 'hasn', 'my', 'then', 'until', 'myself', 'with', 'few', 'mustn', 'this', 'does', "mightn't", 'has', 'won', 'over', 'through', 'further', 'after', "wasn't", 'wouldn', "i've", 'by', 'there', 'nor', 'didn', 'will', "he'd", 'all', 'aren', 'own', 's', 'that', "haven't", 'their', 'itself', 'haven', 'its', 'them', 'too', 'i', 'under', 'some', 'both', 'having', 'during', 'don', 'for', "it'd", "needn't", 'couldn', 'between', "they'll", 'up', 'very', 'shouldn', 'll', 'out', 'was', "you've", 'just', "don't", 'he', "we're", 'any', 'weren', 'ma', "he's", 'from', 'ain', 'yourself', 'here', 'more', 'an', 'is', 'yourselves', 'only', 'most', 'same', 'you', 'of', 'above', 'me', 
# ...

# %%
# import nltk and download punkt
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import unicodedata
import pandas as pd
from transformers import BertTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Load the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# create a text file path
textfile_path='/content/offerings - Reviews_Preprocessed.csv'

# %%
# read text from text file
with open(textfile_path,'r') as file:
  text= file.read()

# %%
# unicode normalization
text=unicodedata.normalize('NFKC',text)

# %%
# Tokenixation using BRET token
tokens=tokenizer.tokenize(text)

# %%
# define a custom list of english stop words
spanish_stopwords=set(stopwords.words('english'))

# %%
# removing stop words using the custom list
filtered_tokens=[token for token in tokens if token.lower() not in english_stopwords]

# %%
# lowecase
filtered_tokens=[token.lower() for token in filtered_tokens]

# %%
# print the cleaned and pre processed tokens
print(filtered_tokens)
# Out:
# ['id', ',', 'name', ',', 'date', ',', 'review', 'title', ',', 'review', ',', 'travel', 'type', ',', 'rating', ',', 'pre', '##pro', '##cesse', '##d', '_', 'reviews', '113', '##31', '##7', ',', 'casablanca', 'hotel', 'times', 'square', ',', 'dec', '19', ',', '"', 'wo', '##w', ',', 'fa', '##bulo', '##us', ',', 'ama', '##zing', 'hotel', ',', 'great', 'location', ',', 'staff', 'super', '##b', '!', 'high', '##ly', '##com', '##mend', '.', '"', ',', '"', 'amazing', 'mother', 'daughter', 'time', 'casablanca', 'hotel', 'celebra', '##ting', 'daughter', '[unk]', '21st', 'birthday', '.', 'back', '!', 'second', 'time', 'hotel', '[unk]', 'disa', '##ppo', '##int', '.', 'front', 'des', '##k', 'staff', ',', 'wo', '##w', ',', 'start', '.', 'fa', '##bulo', '##us', ',', 'nothing', 'much', 'trouble', ',', 'book', '##ing', 'restaurants', ',', 'helping', 'travel', 'arrangements', ',', 'giving', 'advice', 'etc', '.', 'special', 'sh', '##out', '##out', 'go', 'james', '.', 'sorry', 'missed', '[unk]', 'get', 'o
# ...
